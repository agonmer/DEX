# %%
from scipy import stats
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Read the files containing data from the two samples for the U tests.

file_a = 'sample_a_data.csv'
dfa = pd.read_csv(file_a,sep='\t')
file_b = 'sample_b_data.csv'
dfb = pd.read_csv(file_b,sep='\t')

# %%
valid_fields = ['CV_RR0','AF_RR0','CON_RR0','3 ITEMS_RR0','IRR_RR0','INC_RR0','2 ITEMS_RR0','TOT PAED_RR0',
                'CV_RR1','AF_RR1','CON_RR1','IRR_RR1','INC_RR1','TOT PAED_RR1',
                'CV_RR2','AF_RR2','CON_RR2','IRR_RR2','INC_RR2','TOT PAED_RR2',
                'CV_RR3','AF_RR3','CON_RR3','IRR_RR3','INC_RR3','TOT PAED_RR3']

pval_u = []

for kk in range(len(valid_fields)):
    a = dfa[valid_fields[kk]]
    b = dfb[valid_fields[kk]]
    res = stats.mannwhitneyu(a,b)
    pval_u.append(res.pvalue)
    
    print(valid_fields[kk])
    print(res)
    print('------------------------------------------------------------------------------')
    
    fig = plt.figure()
    plt.hist(a,alpha=0.5,label='D')
    plt.hist(b,alpha=0.5,label='K')
    plt.legend(fontsize=14)
    plt.xlabel(valid_fields[kk],fontsize=14)
    plt.title('U test p value = {pval:.3f}'.format(pval = res.pvalue),fontsize=16)
    if valid_fields[kk]=='TOT PAED_RR0':
        figure_name = 'histogram_tot_paed_rr0.png'
        plt.savefig('./figures/'+figure_name,bbox_inches='tight')
    
print(pval_u)
# Out:
# CV_RR0
# MannwhitneyuResult(statistic=68.0, pvalue=0.008675753364262056)
# ------------------------------------------------------------------------------
# AF_RR0
# MannwhitneyuResult(statistic=12.0, pvalue=9.256404337466177e-07)
# ------------------------------------------------------------------------------
# CON_RR0
# MannwhitneyuResult(statistic=66.0, pvalue=0.005873256551633463)
# ------------------------------------------------------------------------------
# 3 ITEMS_RR0
# MannwhitneyuResult(statistic=41.5, pvalue=0.000557844842735524)
# ------------------------------------------------------------------------------
# IRR_RR0
# MannwhitneyuResult(statistic=115.0, pvalue=0.2286366002427599)
# ------------------------------------------------------------------------------
# INC_RR0
# MannwhitneyuResult(statistic=120.0, pvalue=0.22938596910570452)
# ------------------------------------------------------------------------------
# 2 ITEMS_RR0
# MannwhitneyuResult(statistic=117.0, pvalue=0.25762541068319017)
# ------------------------------------------------------------------------------
# TOT PAED_RR0
# MannwhitneyuResult(statistic=30.5, pvalue=0.0001259811922685857)
# ------------------------------------------------------------------------------
# CV_RR1
# MannwhitneyuResult(statistic=95.5, pvalue=0.08581189092841746)
# ------------------------------------------------------------------------------
# AF_RR1
# MannwhitneyuResult(statistic=70.5, pvalue=0.003096741280580429)
# ------------------------------------------------------------------------------
# CON_RR1
# MannwhitneyuResult(statistic=89.5, pvalue=0.05979488238564792)
# ------------------------------------------------------------------------------
# IRR_RR1
# MannwhitneyuResult(statistic=114.0, pvalue=0.2075944369386118)
# ------------------------------------------------------------------------------
# INC_RR1
# MannwhitneyuResult(statistic=113.0, pvalue=0.19479274574082517)
# ------------------------------------------------------------------------------
# TOT PAED_RR1
# MannwhitneyuResult(statistic=81.0, pvalue=0.033192852254615705)
# ------------------------------------------------------------------------------
# CV_RR2
# MannwhitneyuResult(statistic=120.0, pvalue=0.29588983493138254)
# ------------------------------------------------------------------------------
# AF_RR2
# MannwhitneyuResult(statistic=130.5, pvalue=0.4708019624166354)
# ------------------------------------------------------------------------------
# CON_RR2
# MannwhitneyuResult(statistic=130.0, pvalue=0.47464408179012235)
# ------------------------------------------------------------------------------
# IRR_RR2
# MannwhitneyuResult(statistic=93.5, pvalue=0.03174315528027023)
# ------------------------------------------------------------------------------
# INC_RR2
# MannwhitneyuResult(statistic=86.0, pvalue=0.023534902324842576)
# ------------------------------------------------------------------------------
# TOT PAED_RR2
# MannwhitneyuResult(statistic=96.5, pvalue=0.09740969281515705)
# ------------------------------------------------------------------------------
# CV_RR3
# MannwhitneyuResult(statistic=118.0, pvalue=0.21470930009684885)
# ------------------------------------------------------------------------------
# AF_RR3
# MannwhitneyuResult(statistic=130.0, pvalue=0.45626556978937716)
# ------------------------------------------------------------------------------
# CON_RR3
# MannwhitneyuResult(statistic=120.5, pvalue=0.2599185051538686)
# ------------------------------------------------------------------------------
# IRR_RR3
# MannwhitneyuResult(statistic=88.0, pvalue=0.00252526808536726)
# ------------------------------------------------------------------------------
# <ipython-input-12-252b3efefe91>:18: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure()
# INC_RR3
# MannwhitneyuResult(statistic=93.0, pvalue=0.05129569684308723)
# ------------------------------------------------------------------------------
# TOT PAED_RR3
# MannwhitneyuResult(statistic=106.0, pvalue=0.1620198197544072)
# ------------------------------------------------------------------------------
# [0.008675753364262056, 9.256404337466177e-07, 0.005873256551633463, 0.000557844842735524, 0.2286366002427599, 0.22938596910570452, 0.25762541068319017, 0.0001259811922685857, 0.08581189092841746, 0.003096741280580429, 0.05979488238564792, 0.2075944369386118, 0.19479274574082517, 0.033192852254615705, 0.29588983493138254, 0.4708019624166354, 0.47464408179012235, 0.03174315528027023, 0.023534902324842576, 0.09740969281515705, 0.21470930009684885, 0.45626556978937716, 0.2599185051538686, 0.00252526808536726, 0.05129569684308723, 0.1620198197544072]

# %%
# Simple test

a = np.array([9,7,7,10,10,6,5,8,6,1,2,7,3,7,6,3,1,7,3,5,3,4])
b = np.array([13,14,12,12,9,12,10,10,2,1,1,7,12])

res = stats.mannwhitneyu(a,b)
print(res)
# Out:
# MannwhitneyuResult(statistic=72.5, pvalue=0.008117204133496514)

# %%
plt.hist(a,alpha=0.5,label='a')
plt.hist(b,alpha=0.5,label='b')
plt.legend()
